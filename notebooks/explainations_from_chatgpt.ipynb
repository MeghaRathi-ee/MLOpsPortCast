# %% [markdown]
# #### Note: Pearson correlation does not mean causation
# ---
#
# ## What does **causation** mean?
#
# ### **Causation** means:
#
# > **One variable directly causes a change in another variable.**
#
# If **X causes Y**, then:
#
# * Changing **X** will **produce a change in Y**
# * There is a **cause–effect relationship**
#
# Example:
#
# * **Rain → wet roads**
#
#   * Rain **causes** roads to become wet
#
# ---
#
# ## Correlation vs Causation (core difference)
#
# ### 🔹 Correlation
#
# * Variables **move together**
# * No guarantee of cause–effect
#
# ### 🔹 Causation
#
# * One variable **directly influences** the other
#
# ---
#
# ## Simple example (very clear)
#
# ### Correlation but **NOT** causation ❌
#
# * Ice cream sales ↑
# * Drowning incidents ↑
#
# They are correlated, but:
#
# * Ice cream does **not cause** drowning
# * **Hot weather** causes both
#
# 👉 A **third variable** explains the relationship
#
# ---
#
# ### Correlation **WITH** causation ✅
#
# * Rain ↑
# * Road accidents ↑
#
# Rain causes:
#
# * Slippery roads
# * Poor visibility
#
# So here, correlation reflects causation.
#
# ---
#
# ## Why Pearson correlation does **NOT** imply causation
#
# Pearson correlation only tells:
#
# * Strength of **linear relationship**
# * Direction (+ or −)
#
# It does **NOT** tell:
#
# * Which variable causes which
# * Whether a third factor exists
# * Whether the relationship is accidental
#
# ---
#
# ## In ML terms 🧠
#
# * ML models care about **prediction**, not causation
# * A feature can be highly correlated and still:
#
#   * Be a proxy
#   * Be indirectly related
#   * Stop working in production
#
# That’s why causation matters in **real-world systems**
#
# ---
#
# ## Example from your weather project 🌦️
#
# * Humidity ↑ correlates with rain
# * But humidity does **not always cause** rain
# * Both may be caused by:
#
#   * Atmospheric pressure changes
#
# Yet humidity is still useful for **prediction**
#
# ---
#
# ## One-line definition
#
# > **Causation refers to a direct cause-and-effect relationship between variables, whereas correlation only indicates an association without implying that one variable causes changes in another.**
#
# ---
#
# ## TL;DR
#
# * **Correlation** → variables move together
# * **Causation** → one variable causes the other
# * Pearson correlation ≠ causation
# * ML uses correlation, science seeks causation
#
# ---
